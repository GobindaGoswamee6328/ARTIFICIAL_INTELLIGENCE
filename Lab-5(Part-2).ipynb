# %% [markdown]
# # 1.	Generate 100 random integer and 100 random floating-point numbers and save them in separate file. Write two separate functions and save integer in random-int.txt, float in random-float.txt

# %%
import numpy as np

def generate_int(n,file):
    f = open(file,"w")
    for i in range(n):
        f.write(str(np.random.randint(1000))+"\n")
        
 

print(generate_int(10,"h2.txt"))
# Out:
# None

# %% [markdown]
# # 3.	A die was rolled 100 times and saved each outcome in a text file (dice.txt) and calculates the frequency and probability of each outcome using Python program. (Rolling one die by choosing one of the integers 1, 2, 3, 4, 5, or 6 at random).

# %%
import numpy as np

def generate_int(n,file):
    f = open(file,"w")
    for i in range(n):
        f.write(str(np.random.randint(6)+1)+"\n")
        
 

print(generate_int(100,"Dice.txt"))
# Out:
# None

# %% [markdown]
# # 2.	Read 100 numbers from file (random-int.txt) and stores them in array and randomly selects 10 elements from that array and sums them up, print the sum.

# %%
def Dice(n,k):
    L =[]
    Li = []
    for i in range(n):
        L.append(np.random.randint(6)+1)
        
    Li = np.random.choice(L,k)
    return L,sum(Li)

list,List10 = Dice(100,10)
print(List)
print(List10)
# Out:
# 1
# 30

# %% [markdown]
# # Numerical Math

# %%
def f(x):
    return x**4-4*x**2-7

def f_prime(x):
    return 2*x-4

x = np.linspace(-20,20,1000)
y = f(x)
y_prime = f_prime(x)

import matplotlib.pyplot as plt
plt.plot(x,y)
plt.grid()
plt.show()
